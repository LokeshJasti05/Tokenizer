# %% [markdown]
# the below code will convert the text into initial tokens for example "I am" is the text then I will be 1 token , space will be one token and so on.

# %%
# text from https://www.reedbeta.com/blog/programmers-intro-to-unicode/
text = "Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪!  The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception."
tokens = text.encode("utf-8") # raw bytes
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience
print('---')
print(text)
print("length:", len(text))
print('---')
print(tokens)
print("length:", len(tokens))
# Out:
# ---
# Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception.
# length: 533
# ---
# [239, 188, 181, 239, 189, 142, 239, 189, 137, 239, 189, 131, 239, 189, 143, 239, 189, 132, 239, 189, 133, 33, 32, 240, 159, 133, 164, 240, 159, 133, 157, 240, 159, 133, 152, 240, 159, 133, 146, 240, 159, 133, 158, 240, 159, 133, 147, 240, 159, 133, 148, 226, 128, 189, 32, 240, 159, 135, 186, 226, 128, 140, 240, 159, 135, 179, 226, 128, 140, 240, 159, 135, 174, 226, 128, 140, 240, 159, 135, 168, 226, 128, 140, 240, 159, 135, 180, 226, 128, 140, 240, 159, 135, 169, 226, 128, 140, 240, 159, 135, 170, 33, 32, 240, 159, 152, 132, 32, 84, 104, 101, 32, 118, 101, 114, 121, 32, 110, 97, 109, 101, 32, 115, 116, 114, 105, 107, 101, 115, 32, 102, 101, 97, 114, 32, 97, 110, 100, 32, 97, 119, 101, 32, 105, 110, 116, 111, 32, 116, 104, 101, 32, 104, 101, 97, 114, 116, 115, 32, 111, 102, 32, 112, 114, 111, 103, 114, 97, 109, 109, 101, 114, 115, 32, 119, 111, 114, 108, 100, 119, 105, 100, 101, 46, 32, 87, 101, 32, 97, 108, 108, 32, 107, 110, 111, 119, 32, 119, 101, 32, 111, 117, 103, 104, 116, 32, 116, 111, 32, 226, 128, 156, 115, 117, 112, 112, 111, 114, 116, 32, 85, 110, 105, 99, 111, 100, 101, 226, 128, 157, 32, 105, 110, 32, 111, 117, 114, 32, 115, 111, 102, 116, 119, 97, 114, 101, 32, 40, 119, 104, 97, 116, 101, 118, 101, 114, 32, 116, 104, 97, 116, 32, 109, 101, 97, 110, 115, 226, 128, 148, 108, 105, 107, 101, 32
don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception.  A few months ago, I got interested in Unicode and decided to spend some time learning more about it in detail. In this article, I’ll give an introduction to it from a programmer’s point of view.  I’m going to focus on the character set and what’s involved in working with strings and files of Unicode text. However, in this article I’m not going to talk about fonts, text layout/shaping/rendering, or localization in detail—those are separate issues, beyond my scope (and knowledge) here.  Diversity and Inherent Complexity The Unicode Codespace Codespace Allocation Scripts Usage Frequency Encodings UTF-8 UTF-16 Combining Marks Canonical Equivalence Normalization Forms Grapheme Clusters And More… Diversity and Inherent Complexity As soon as you start to study Unicode, it becomes clear that it represents a large jump in complexity over character sets like ASCII that you may be more familiar with. It’s not just that Unicode contains a much larger number of characters, although that’s part of it. Unicode also has a great deal of internal structure, features, and special cases, making it much more than what one might expect a mere “character set” to be. We’ll see some of that later in this article.  When confronting all this complexity, especially as an engineer, it’s hard not to find oneself asking, “Why do we need all this? Is this really necessary? Couldn’t it be simplified?”  However, Unicode aims to faithfully represent the entire world’s writing systems. The Unicode Consortium’s stated goal is “enabling people around the world to use computers in any language”. And as you might imagine, the diversity of written languages is immense! To date, Unicode supports 135 different scripts, covering some 1100 languages, and there’s still a long tail of over 100 unsupported scripts, both modern and historical, which people are still working to add.  Given this enormous diversity, it’s inevitable that representing it is a complicated project. Unicode embraces that diversity, and accepts the complexity inherent in its mission to include all human writing systems. It doesn’t make a lot of trade-offs in the name of simplification, and it makes exceptions to its own rules where necessary to further its mission.  Moreover, Unicode is committed not just to supporting texts in any single language, but also to letting multiple languages coexist within one text—which introduces even more complexity.  Most programming languages have libraries available to handle the gory low-level details of text manipulation, but as a programmer, you’ll still need to know about certain Unicode features in order to know when and how to apply them. It may take some time to wrap your head around it all, but don’t be discouraged—think about the billions of people for whom your software will be more accessible through supporting text in their language. Embrace the complexity!  The Unicode Codespace Let’s start with some general orientation. The basic elements of Unicode—its “characters”, although that term isn’t quite right—are called code points. Code points are identified by number, customarily written in hexadecimal with the prefix “U+”, such as U+0041 “A” latin capital letter a or U+03B8 “θ” greek small letter theta. Each code point also has a short name, and quite a few other properties, specified in the Unicode Character Database.  The set of all possible code points is called the codespace. The Unicode codespace consists of 1,114,112 code points. However, only 128,237 of them—about 12% of the codespace—are actually assigned, to date. There’s plenty of room for growth! Unicode also reserves an additional 137,468 code points as “private use” areas, which have no standardized meaning and are available for individual applications to define for their own purposes.  Codespace Allocation To get a feel for how the codespace is laid out, it’s helpful to visualize it. Below is a map of the entire codespace, with one pixel per code point. It’s arranged in tiles for visual coherence; each small square is 16×16 = 256 code points, and each large square is a “plane” of 65,536 code points. There are 17 planes altogether.  Map of the Unicode codespace (click to zoom)  White represents unassigned space. Blue is assigned code points, green is private-use areas, and the small red area is surrogates (more about those later). As you can see, the assigned code points are distributed somewhat sparsely, but concentrated in the first three planes.  Plane 0 is also known as the “Basic Multilingual Plane”, or BMP. The BMP contains essentially all the characters needed for modern text in any script, including Latin, Cyrillic, Greek, Han (Chinese), Japanese, Korean, Arabic, Hebrew, Devanagari (Indian), and many more.  (In the past, the codespace was just the BMP and no more—Unicode was originally conceived as a straightforward 16-bit encoding, with only 65,536 code points. It was expanded to its current size in 1996. However, the vast majority of code points in modern text belong to the BMP.)  Plane 1 contains historical scripts, such as Sumerian cuneiform and Egyptian hieroglyphs, as well as emoji and various other symbols. Plane 2 contains a large block of less-common and historical Han characters. The remaining planes are empty, except for a small number of rarely-used formatting characters in Plane 14; planes 15–16 are reserved entirely for private use.  Scripts Let’s zoom in on the first three planes, since that’s where the action is:  Map of scripts in Unicode planes 0–2 (click to zoom)  This map color-codes the 135 different scripts in Unicode. You can see how Han () and Korean () take up most of the range of the BMP (the left large square). By contrast, all of the European, Middle Eastern, and South Asian scripts fit into the first row of the BMP in this diagram.  Many areas of the codespace are adapted or copied from earlier encodings. For example, the first 128 code points of Unicode are just a copy of ASCII. This has clear benefits for compatibility—it’s easy to losslessly convert texts from smaller encodings into Unicode (and the other direction too, as long as no characters outside the smaller encoding are used).  Usage Frequency One more interesting way to visualize the codespace is to look at the distribution of usage—in other words, how often each code point is actually used in real-world texts. Below is a heat map of planes 0–2 based on a large sample of text from Wikipedia and Twitter (all languages). Frequency increases from black (never seen) through red and yellow to white.  Heat map of code point usage frequency in Unicode planes 0–2 (click to zoom)  You can see that the vast majority of this text sample lies in the BMP, with only scattered usage of code points from planes 1–2. The biggest exception is emoji, which show up here as the several bright squares in the bottom row of plane 1.  Encodings We’ve seen that Unicode code points are abstractly identified by their index in the codespace, ranging from U+0000 to U+10FFFF. But how do code points get represented as bytes, in memory or in a file?  The most convenient, computer-friendliest (and programmer-friendliest) thing to do would be to just store the code point index as a 32-bit integer. This works, but it consumes 4 bytes per code point, which is sort of a lot. Using 32-bit ints for Unicode will cost you a bunch of extra storage, memory, and performance in bandwidth-bound scenarios, if you work with a lot of text.  Consequently, there are several more-compact encodings for Unicode. The 32-bit integer encoding is officially called UTF-32 (UTF = “Unicode Transformation Format”), but it’s rarely used for storage. At most, it comes up sometimes as a temporary internal representation, for examining or operating on the code points in a string.  Much more commonly, you’ll see Unicode text encoded as either UTF-8 or UTF-16. These are both variable-length encodings, made up of 8-bit or 16-bit units, respectively. In these schemes, code points with smaller index values take up fewer bytes, which saves a lot of memory for typical texts. The trade-off is that processing UTF-8/16 texts is more programmatically involved, and likely slower.  UTF-8 In UTF-8, each code point is stored using 1 to 4 bytes, based on its index value.  UTF-8 uses a system of binary prefixes, in which the high bits of each byte mark whether it’s a single byte, the beginning of a multi-byte sequence, or a continuation byte; the remaining bits, concatenated, give the code point index. This table shows how it works:  UTF-8 (binary)\tCode point (binary)\tRange 0xxxxxxx\txxxxxxx\tU+0000–U+007F 110xxxxx 10yyyyyy\txxxxxyyyyyy\tU+0080–U+07FF 1110xxxx 10yyyyyy 10zzzzzz\txxxxyyyyyyzzzzzz\tU+0800–U+FFFF 11110xxx 10yyyyyy 10zzzzzz 10wwwwww\txxxyyyyyyzzzzzzwwwwww\tU+10000–U+10FFFF A handy property of UTF-8 is that code points below 128 (ASCII characters) are encoded as single bytes, and all non-ASCII code points are encoded using sequences of bytes 128–255. This has a couple of nice consequences. First, any strings or files out there that are already in ASCII can also be interpreted as UTF-8 without any conversion. Second, lots of widely-used string programming idioms—such as null termination, or delimiters (newlines, tabs, commas, slashes, etc.)—will just work on UTF-8 strings. ASCII bytes never occur inside the encoding of non-ASCII code points, so searching byte-wise for a null terminator or a delimiter will do the right thing.  Thanks to this convenience, it’s relatively simple to extend legacy ASCII programs and APIs to handle UTF-8 strings. UTF-8 is very widely used in the Unix/Linux and Web worlds, and many programmers argue UTF-8 should be the default encoding everywhere.  However, UTF-8 isn’t a drop-in replacement for ASCII strings in all respects. For instance, code that iterates over the “characters” in a string will need to decode UTF-8 and iterate over code points (or maybe grapheme clusters—more about those later), not bytes. When you measure the “length” of a string, you’ll need to think about whether you want the length in bytes, the length in code points, the width of the text when rendered, or something else.  UTF-16 The other encoding that you’re likely to encounter is UTF-16. It uses 16-bit words, with each code point stored as either 1 or 2 words.  Like UTF-8, we can express the UTF-16 encoding rules in the form of binary prefixes:  UTF-16 (binary)\tCode point (binary)\tRange xxxxxxxxxxxxxxxx\txxxxxxxxxxxxxxxx\tU+0000–U+FFFF 110110xxxxxxxxxx 110111yyyyyyyyyy\txxxxxxxxxxyyyyyyyyyy + 0x10000\tU+10000–U+10FFFF A more common way that people talk about UTF-16 encoding, though, is in terms of code points called “surrogates”. All the code points in the range U+D800–U+DFFF—or in other words, the code points that match the binary prefixes 110110 and 110111 in the table above—are reserved specifically for UTF-16 encoding, and don’t represent any valid characters on their own. They’re only meant to occur in the 2-word encoding pattern above, which is called a “surrogate pair”. Surrogate code points are illegal in any other context! They’re not allowed in UTF-8 or UTF-32 at all.  Historically, UTF-16 is a descendant of the original, pre-1996 versions of Unicode, in which there were only 65,536 code points. The original intention was that there would be no different “encodings”; Unicode was supposed to be a straightforward 16-bit character set. Later, the codespace was expanded to make room for a long tail of less-common (but still important) Han characters, which the Unicode designers didn’t originally plan for. Surrogates were then introduced, as—to put it bluntly—a kludge, allowing 16-bit encodings to access the new code points.  Today, Javascript uses UTF-16 as its standard string representation: if you ask for the length of a string, or iterate over it, etc., the result will be in UTF-16 words, with any code points outside the BMP expressed as surrogate pairs. UTF-16 is also used by the Microsoft Win32 APIs; though Win32 supports either 8-bit or 16-bit strings, the 8-bit version unaccountably still doesn’t support UTF-8—only legacy code-page encodings, like ANSI. This leaves UTF-16 as the only way to get proper Unicode support in Windows. (Update: in Win10 version 1903, they finally added UTF-8 support to the 8-bit APIs! 😊)  By the way, UTF-16’s words can be stored either little-endian or big-endian. Unicode has no opinion on that issue, though it does encourage the convention of putting U+FEFF zero width no-break space at the top of a UTF-16 file as a byte-order mark, to disambiguate the endianness. (If the file doesn’t match the system’s endianness, the BOM will be decoded as U+FFFE, which isn’t a valid code point.)  Combining Marks In the story so far, we’ve been focusing on code points. But in Unicode, a “character” can be more complicated than just an individual code point!  Unicode includes a system for dynamically composing characters, by combining multiple code points together. This is used in various ways to gain flexibility without causing a huge combinatorial explosion in the number of code points.  In European languages, for example, this shows up in the application of diacritics to letters. Unicode supports a wide range of diacritics, including acute and grave accents, umlauts, cedillas, and many more. All these diacritics can be applied to any letter of any alphabet—and in fact, multiple diacritics can be used on a single letter.  If Unicode tried to assign a distinct code point to every possible combination of letter and diacritics, things would rapidly get out of hand. Instead, the dynamic composition system enables you to construct the character you want, by starting with a base code point (the letter) and appending additional code points, called “combining marks”, to specify the diacritics. When a text renderer sees a sequence like this in a string, it automatically stacks the diacritics over or under the base letter to create a composed character.  For example, the accented character “Á” can be expressed as a string of two code points: U+0041 “A” latin capital letter a plus U+0301 “◌́” combining acute accent. This string automatically gets rendered as a single character: “Á”.  Now, Unicode does also include many “precomposed” code points, each representing a letter with some combination of diacritics already applied, such as U+00C1 “Á” latin capital letter a with acute or U+1EC7 “ệ” latin small letter e with circumflex and dot below. I suspect these are mostly inherited from older encodings that were assimilated into Unicode, and kept around for compatibility. In practice, there are precomposed code points for most of the common letter-with-diacritic combinations in European-script languages, so they don’t use dynamic composition that much in typical text.  Still, the system of combining marks does allow for an arbitrary number of diacritics to be stacked on any base character. The reductio-ad-absurdum of this is Zalgo text, which works by ͖͟ͅr͞aṋ̫̠̖͈̗d͖̻̹óm̪͙͕̗̝ļ͇̰͓̳̫ý͓̥̟͍ ̕s̫t̫̱͕̗̰̼̘͜a̼̩͖͇̠͈̣͝c̙͍k̖̱̹͍͘i̢n̨̺̝͇͇̟͙ģ̫̮͎̻̟ͅ ̕n̼̺͈͞u̮͙m̺̭̟̗͞e̞͓̰̤͓̫r̵o̖ṷs҉̪͍̭̬̝̤ ̮͉̝̞̗̟͠d̴̟̜̱͕͚i͇̫̼̯̭̜͡ḁ͙̻̼c̲̲̹r̨̠̹̣̰̦i̱t̤̻̤͍͙̘̕i̵̜̭̤̱͎c̵s ͘o̱̲͈̙͖͇̲͢n͘ ̜͈e̬̲̠̩ac͕̺̠͉h̷̪ ̺̣͖̱ḻ̫̬̝̹ḙ̙̺͙̭͓̲t̞̞͇̲͉͍t̷͔̪͉̲̻̠͙e̦̻͈͉͇r͇̭̭̬͖,̖́ ̜͙͓̣̭s̘̘͈o̱̰̤̲ͅ ̛̬̜̙t̼̦͕̱̹͕̥h̳̲͈͝ͅa̦t̻̲ ̻̟̭̦̖t̛̰̩h̠͕̳̝̫͕e͈̤̘͖̞͘y҉̝͙ ̷͉͔̰̠o̞̰v͈͈̳̘͜er̶f̰͈͔ḻ͕̘̫̺̲o̲̭͙͠ͅw̱̳̺ ͜t̸h͇̭͕̳͍e̖̯̟̠ ͍̞̜͔̩̪͜ļ͎̪̲͚i̝̲̹̙̩̹n̨̦̩̖ḙ̼̲̼͢ͅ ̬͝s̼͚̘̞͝p͙̘̻a̙c҉͉̜̤͈̯̖i̥͡n̦̠̱͟g̸̗̻̦̭̮̟ͅ ̳̪̠͖̳̯̕a̫͜n͝d͡ ̣̦̙ͅc̪̗r̴͙̮̦̹̳e͇͚̞͔̹̫͟a̙̺̙ț͔͎̘̹ͅe̥̩͍ a͖̪̜̮͙̹n̢͉̝ ͇͉͓̦̼́a̳͖̪̤̱p̖͔͔̟͇͎͠p̱͍̺ę̲͎͈̰̲̤̫a̯͜r̨̮̫̣̘a̩̯͖n̹̦̰͎̣̞̞c̨̦̱͔͎͍͖e̬͓͘ ̤̰̩͙̤̬͙o̵̼̻̬̻͇̮̪f̴ ̡̙̭͓͖̪̤“̸͙̠̼c̳̗͜o͏̼͙͔̮r̞̫̺̞̥̬ru̺̻̯͉̭̻̯p̰̥͓̣̫̙̤͢t̳͍̳̖ͅi̶͈̝͙̼̙̹o̡͔n̙̺̹̖̩͝ͅ”̨̗͖͚̩.̯͓  A few other places where dynamic character composition shows up in Unicode:  Vowel-pointing notation in Arabic and Hebrew. In these languages, words are normally spelled with some of their vowels left out. They then have diacritic notation to indicate the vowels (used in dictionaries, language-teaching materials, children’s books, and such). These diacritics are expressed with combining marks.  A Hebrew example, with niqqud:\tאֶת דַלְתִּי הֵזִיז הֵנִיעַ, קֶטֶב לִשְׁכַּתִּי יָשׁוֹד Normal writing (no niqqud):\tאת דלתי הזיז הניע, קטב לשכתי ישוד Devanagari, the script used to write Hindi, Sanskrit, and many other South Asian languages, expresses certain vowels as combining marks attached to consonant letters. For example, “ह” + “\u200bि” = “हि” (“h” + “i” = “hi”). Korean characters stand for syllables, but they are composed of letters called jamo that stand for the vowels and consonants in the syllable. While there are code points for precomposed Korean syllables, it’s also possible to dynamically compose them by concatenating their jamo. For example, “ᄒ” + “ᅡ” + “ᆫ” = “한” (“h” + “a” + “n” = “han”). Canonical Equivalence In Unicode, precomposed characters exist alongside the dynamic composition system. A consequence of this is that there are multiple ways to express “the same” string—different sequences of code points that result in the same user-perceived characters. For example, as we saw earlier, we can express the character “Á” either as the single code point U+00C1, or as the string of two code points U+0041 U+0301.  Another source of ambiguity is the ordering of multiple diacritics in a single character. Diacritic order matters visually when two diacritics apply to the same side of the base character, e.g. both above: “ǡ” (dot, then macron) is different from “ā̇” (macron, then dot). However, when diacritics apply to different sides of the character, e.g. one above and one below, then the order doesn’t affect rendering. Moreover, a character with multiple diacritics might have one of the diacritics precomposed and others expressed as combining marks.  For example, the Vietnamese letter “ệ” can be expressed in five different ways:  Fully precomposed: U+1EC7 “ệ” Partially precomposed: U+1EB9 “ẹ” + U+0302 “◌̂” Partially precomposed: U+00EA “ê” + U+0323 “◌̣” Fully decomposed: U+0065 “e” + U+0323 “◌̣” + U+0302 “◌̂” Fully decomposed: U+0065 “e” + U+0302 “◌̂” + U+0323 “◌̣” Unicode refers to set of strings like this as “canonically equivalent”. Canonically equivalent strings are supposed to be treated as identical for purposes of searching, sorting, rendering, text selection, and so on. This has implications for how you implement operations on text. For example, if an app has a “find in file” operation and the user searches for “ệ”, it should, by default, find occurrences of any of the five versions of “ệ” above!  Normalization Forms To address the problem of “how to handle canonically equivalent strings”, Unicode defines several normalization forms: ways of converting strings into a canonical form so that they can be compared code-point-by-code-point (or byte-by-byte).  The “NFD” normalization form fully decomposes every character down to its component base and combining marks, taking apart any precomposed code points in the string. It also sorts the combining marks in each character according to their rendered position, so e.g. diacritics that go below the character come before the ones that go above the character. (It doesn’t reorder diacritics in the same rendered position, since their order matters visually, as previously mentioned.)  The “NFC” form, conversely, puts things back together into precomposed code points as much as possible. If an unusual combination of diacritics is called for, there may not be any precomposed code point for it, in which case NFC still precomposes what it can and leaves any remaining combining marks in place (again ordered by rendered position, as in NFD).  There are also forms called NFKD and NFKC. The “K” here refers to compatibility decompositions, which cover characters that are “similar” in some sense but not visually identical. However, I’m not going to cover that here.  Grapheme Clusters As we’ve seen, Unicode contains various cases where a thing that a user thinks of as a single “character” might actually be made up of multiple code points under the hood. Unicode formalizes this using the notion of a grapheme cluster: a string of one or more code points that constitute a single “user-perceived character”.  UAX #29 defines the rules for what, precisely, qualifies as a grapheme cluster. It’s approximately “a base code point followed by any number of combining marks”, but the actual definition is a bit more complicated; it accounts for things like Korean jamo, and emoji ZWJ sequences.  The main thing grapheme clusters are used for is text editing: they’re often the most sensible unit for cursor placement and text selection boundaries. Using grapheme clusters for these purposes ensures that you can’t accidentally chop off some diacritics when you copy-and-paste text, that left/right arrow keys always move the cursor by one visible character, and so on.  Another place where grapheme clusters are useful is in enforcing a string length limit—say, on a database field. While the true, underlying limit might be something like the byte length of the string in UTF-8, you wouldn’t want to enforce that by just truncating bytes. At a minimum, you’d want to “round down” to the nearest code point boundary; but even better, round down to the nearest grapheme cluster boundary. Otherwise, you might be corrupting the last character by cutting off a diacritic, or interrupting a jamo sequence or ZWJ sequence.  And More… There’s much more that could be said about Unicode from a programmer’s perspective! I haven’t gotten into such fun topics as case mapping, collation, compatibility decompositions and confusables, Unicode-aware regexes, or bidirectional text. Nor have I said anything yet about implementation issues—how to efficiently store and look-up data about the sparsely-assigned code points, or how to optimize UTF-8 decoding, string comparison, or NFC normalization. Perhaps I’ll return to some of those things in future posts.  Unicode is a fascinating and complex system. It has a many-to-one mapping between bytes and code points, and on top of that a many-to-one (or, under some circumstances, many-to-many) mapping between code points and “characters”. It has oddball special cases in every corner. But no one ever claimed that representing all written languages was going to be easy, and it’s clear that we’re never going back to the bad old days of a patchwork of incompatible encodings.  Further reading:  The Unicode Standard UTF-8 Everywhere Manifesto Dark corners of Unicode by Eevee ICU (International Components for Unicode)—C/C++/Java libraries implementing many Unicode algorithms and related things Python 3 Unicode Howto Google Noto Fonts—set of fonts intended to cover all assigned code points"""
tokens = text.encode("utf-8") # raw bytes
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience

# %%
# ---
vocab_size = 1000 # the desired final vocabulary size
num_merges = vocab_size - 256
ids = list(tokens) # copy so we don't destroy the original list

merges = {} # (int, int) -> int
for i in range(num_merges):
  stats = get_stats(ids)
  pair = max(stats, key=stats.get)
  idx = 256 + i
  print(f"merging {pair} into a new token {idx}")
  ids = merge(ids, pair, idx)
  merges[pair] = idx
# Out:
# merging (101, 32) into a new token 256
# merging (105, 110) into a new token 257
# merging (115, 32) into a new token 258
# merging (116, 104) into a new token 259
# merging (101, 114) into a new token 260
# merging (99, 111) into a new token 261
# merging (116, 32) into a new token 262
# merging (226, 128) into a new token 263
# merging (44, 32) into a new token 264
# merging (97, 110) into a new token 265
# merging (111, 114) into a new token 266
# merging (100, 32) into a new token 267
# merging (97, 114) into a new token 268
# merging (101, 110) into a new token 269
# merging (257, 103) into a new token 270
# merging (261, 100) into a new token 271
# merging (121, 32) into a new token 272
# merging (46, 32) into a new token 273
# merging (97, 108) into a new token 274
# merging (259, 256) into a new token 275
# merging (111, 110) into a new token 276
# merging (111, 32) into a new token 277
# merging (116, 105) into a new token 278
# merging (97, 99) into a new token 279
# merging (101, 115) into a new token 280
# merging (111, 102) into a new token 281
# merging (271, 256) into a new token 282
# merging (112, 111) into a new token 283
# merging (270, 32) into a new token 284
# merging (281, 32) into a new token 285
# merging (101, 267) into a new token 286
# merging (116, 260) into a new token 287
# merging (116, 277) into a new token 288
# merging (257, 32) into a new token 289
# merging (97, 32) into a new token 290
# merging (266, 32) into a new token 291
# merging (115, 116) into a new token 292
# merging (111, 117) into a new token 293
# merging (99, 104) into a new token 294
# merging (120, 120) into a new token 295
# merging (101, 120) into a new token 296
# merging (101, 258) into a new token 297
# merging (263, 156) into a new token 298
# merging (263, 157) into a new token 299
# merging (261, 109) into a new token 300
# merging (265, 267) into a new token 301
# merging (112, 108) into a new token 302
# merging (105, 116) into a new token 303
# merging (283, 257) into a new token 304
# merging (114, 101) into a new token 305
# merging (263, 153) into a new token 306
# merging (110, 105) into a new token 307
# merging (274, 108) into a new token 308
# merging (97, 116) into a new token 309
# merging (260, 32) into a new token 310
# merging (105, 258) into a new token 311
# merging (282, 304) into a new token 312
# merging (97, 258) into a new token 313
# merging (85, 307) into a new token 314
# merging (278, 276) into a new token 315
# merging (100, 105) into a new token 316
# merging (111, 119) into a new token 317
# merging (116, 258) into a new token 318
# merging (117, 115) into a new token 319
# merging (299, 32) into a new token 320
# merging (114, 105) into a new token 321
# merging (115, 101) into a new token 322
# merging (115, 105) into a new token 323
# merging (97, 109) into a new token 324
# merging (97, 262) into a new token 325
# merging (114, 111) into a new token 326
# merging (314, 282) into a new token 327
# merging (115, 264) into a new token 328
# merging (121, 121) into a new token 329
# merging (108, 108) into a new token 330
# merging (273, 32) into a new token 331
# merging (265, 32) into a new token 332
# merging (108, 101) into a new token 333
# merging (294, 268) into a new token 334
# merging (279, 287) into a new token 335
# merging (84, 104) into a new token 336
# merging (102, 291) into a new token 337
# merging (97, 98) into a new token 338
# merging (334, 335) into a new token 339
# merging (85, 84) into a new token 340
# merging (340, 70) into a new token 341
# merging (119, 105) into a new token 342
# merging (341, 45) into a new token 343
# merging (85, 43) into a new token 344
# merging (268, 256) into a new token 345
# merging (259, 325) into a new token 346
# merging (97, 112) into a new token 347
# merging (119, 104) into a new token 348
# merging (101, 109) into a new token 349
# merging (115, 117) into a new token 350
# merging (105, 99) into a new token 351
# merging (274, 32) into a new token 352
# merging (97, 115) into a new token 353
# merging (32, 285) into a new token 354
# merging (32, 298) into a new token 355
# merging (105, 262) into a new token 356
# merging (111, 109) into a new token 357
# merging (118, 260) into a new token 358
# merging (292, 114) into a new token 359
# merging (101, 264) into a new token 360
# merging (108, 256) into a new token 361
# merging (278, 99) into a new token 362
# merging (48, 48) into a new token 363
# merging (97, 103) into a new token 364
# merging (97, 315) into a new token 365
# merging (261, 110) into a new token 366
# merging (101, 108) into a new token 367
# merging (295, 295) into a new token 368
# merging (306, 258) into a new token 369
# merging (98, 256) into a new token 370
# merging (294, 32) into a new token 371
# merging (269, 32) into a new token 372
# merging (259, 32) into a new token 373
# merging (113, 117) into a new token 374
# merging (114, 280) into a new token 375
# merging (312, 318) into a new token 376
# merging (116, 296) into a new token 377
# merging (263, 148) into a new token 378
# merging (280, 264) into a new token 379
# merging (330, 32) into a new token 380
# merging (276, 32) into a new token 381
# merging (49, 54) into a new token 382
# merging (98, 257) into a new token 383
# merging (308, 272) into a new token 384
# merging (273, 336) into a new token 385
# merging (300, 283) into a new token 386
# merging (121, 293) into a new token 387
# merging (100, 101) into a new token 388
# merging (265, 272) into a new token 389
# merging (279, 321) into a new token 390
# merging (390, 362) into a new token 391
# merging (103, 104) into a new token 392
# merging (102, 105) into a new token 393
# merging (343, 56) into a new token 394
# merging (266, 109) into a new token 395
# merging (260, 256) into a new token 396
# merging (312, 116) into a new token 397
# merging (269, 271) into a new token 398
# merging (98, 121) into a new token 399
# merging (316, 391) into a new token 400
# merging (103, 114) into a new token 401
# merging (32, 288) into a new token 402
# merging (119, 266) into a new token 403
# merging (265, 103) into a new token 404
# merging (259, 310) into a new token 405
# merging (70, 70) into a new token 406
# merging (269, 116) into a new token 407
# merging (109, 266) into a new token 408
# merging (112, 101) into a new token 409
# merging (117, 108) into a new token 410
# merging (112, 305) into a new token 411
# merging (399, 116) into a new token 412
# merging (122, 122) into a new token 413
# merging (32, 115) into a new token 414
# merging (108, 105) into a new token 415
# merging (269, 262) into a new token 416
# merging (112, 375) into a new token 417
# merging (109, 97) into a new token 418
# merging (49, 49) into a new token 419
# merging (153, 204) into a new token 420
# merging (112, 326) into a new token 421
# merging (273, 73) into a new token 422
# merging (110, 32) into a new token 423
# merging (342, 373) into a new token 424
# merging (112, 279) into a new token 425
# merging (269, 99) into a new token 426
# merging (117, 114) into a new token 427
# merging (32, 32) into a new token 428
# merging (359, 270) into a new token 429
# merging (306, 262) into a new token 430
# merging (116, 97) into a new token 431
# merging (115, 277) into a new token 432
# merging (289, 275) into a new token 433
# merging (333, 116) into a new token 434
# merging (101, 105) into a new token 435
# merging (329, 329) into a new token 436
# merging (204, 178) into a new token 437
# merging (240, 159) into a new token 438
# merging (308, 32) into a new token 439
# merging (317, 32) into a new token 440
# merging (117, 262) into a new token 441
# merging (99, 332) into a new token 442
# merging (110, 111) into a new token 443
# merging (408, 256) into a new token 444
# merging (293, 262) into a new token 445
# merging (105, 108) into a new token 446
# merging (118, 256) into a new token 447
# merging (394, 32) into a new token 448
# merging (121, 264) into a new token 449
# merging (117, 110) into a new token 450
# merging (99, 108) into a new token 451
# merging (115, 273) into a new token 452
# merging (434, 287) into a new token 453
# merging (115, 286) into a new token 454
# merging (300, 383) into a new token 455
# merging (400, 258) into a new token 456
# merging (204, 171) into a new token 457
# merging (259, 311) into a new token 458
# merging (100, 260) into a new token 459
# merging (280, 425) into a new token 460
# merging (343, 382) into a new token 461
# merging (387, 32) into a new token 462
# merging (117, 109) into a new token 463
# merging (110, 101) into a new token 464
# merging (302, 256) into a new token 465
# merging (108, 272) into a new token 466
# merging (45, 98) into a new token 467
# merging (205, 136) into a new token 468
# merging (118, 310) into a new token 469
# merging (265, 100) into a new token 470
# merging (268, 107) into a new token 471
# merging (313, 290) into a new token 472
# merging (105, 109) into a new token 473
# merging (108, 404) into a new token 474
# merging (474, 117) into a new token 475
# merging (475, 364) into a new token 476
# merging (348, 105) into a new token 477
# merging (477, 371) into a new token 478
# merging (98, 272) into a new token 479
# merging (32, 344) into a new token 480
# merging (205, 150) into a new token 481
# merging (205, 135) into a new token 482
# merging (32, 204) into a new token 483
# merging (204, 177) into a new token 484
# merging (32, 301) into a new token 485
# merging (350, 112) into a new token 486
# merging (112, 266) into a new token 487
# merging (314, 271) into a new token 488
# merging (107, 256) into a new token 489
# merging (284, 109) into a new token 490
# merging (115, 357) into a new token 491
# merging (377, 262) into a new token 492
# merging (105, 115) into a new token 493
# merging (303, 272) into a new token 494
# merging (374, 426) into a new token 495
# merging (100, 256) into a new token 496
# merging (312, 262) into a new token 497
# merging (467, 356) into a new token 498
# merging (263, 147) into a new token 499
# merging (204, 185) into a new token 500
# merging (204, 176) into a new token 501
# merging (204, 158) into a new token 502
# merging (204, 166) into a new token 503
# merging (401, 324) into a new token 504
# merging (100, 111) into a new token 505
# merging (258, 285) into a new token 506
# merging (338, 445) into a new token 507
# merging (262, 285) into a new token 508
# merging (274, 105) into a new token 509
# merging (99, 321) into a new token 510
# merging (510, 112) into a new token 511
# merging (461, 32) into a new token 512
# merging (116, 284) into a new token 513
# merging (101, 100) into a new token 514
# merging (292, 266) into a new token 515
# merging (398, 270) into a new token 516
# merging (411, 386) into a new token 517
# merging (204, 187) into a new token 518
# merging (204, 170) into a new token 519
# merging (204, 179) into a new token 520
# merging (205, 141) into a new token 521
# merging (204, 188) into a new token 522
# merging (204, 173) into a new token 523
# merging (320, 43) into a new token 524
# merging (50, 32) into a new token 525
# merging (421, 504) into a new token 526
# merging (105, 100) into a new token 527
# merging (286, 288) into a new token 528
# merging (109, 32) into a new token 529
# merging (339, 32) into a new token 530
# merging (377, 116) into a new token 531
# merging (101, 358) into a new token 532
# merging (365, 32) into a new token 533
# merging (309, 256) into a new token 534
# merging (460, 256) into a new token 535
# merging (274, 432) into a new token 536
# merging (409, 99) into a new token 537
# merging (276, 256) into a new token 538
# merging (110, 430) into a new token 539
# merging (385, 256) into a new token 540
# merging (97, 100) into a new token 541
# merging (98, 441) into a new token 542
# merging (268, 105) into a new token 543
# merging (279, 104) into a new token 544
# merging (302, 265) into a new token 545
# merging (117, 116) into a new token 546
# merging (102, 395) into a new token 547
# merging (117, 112) into a new token 548
# merging (49, 48) into a new token 549
# merging (205, 133) into a new token 550
# merging (204, 160) into a new token 551
# merging (204, 150) into a new token 552
# merging (205, 147) into a new token 553
# merging (204, 164) into a new token 554
# merging (205, 148) into a new token 555
# merging (336, 256) into a new token 556
# merging (110, 324) into a new token 557
# merging (392, 262) into a new token 558
# merging (486, 487) into a new token 559
# merging (303, 258) into a new token 560
# merging (290, 108) into a new token 561
# merging (73, 32) into a new token 562
# merging (491, 256) into a new token 563
# merging (102, 326) into a new token 564
# merging (107, 32) into a new token 565
# merging (114, 269) into a new token 566
# merging (111, 115) into a new token 567
# merging (260, 416) into a new token 568
# merging (305, 417) into a new token 569
# merging (264, 301) into a new token 570
# merging (258, 288) into a new token 571
# merging (115, 121) into a new token 572
# merging (300, 112) into a new token 573
# merging (100, 310) into a new token 574
# merging (48, 51) into a new token 575
# merging (116, 111) into a new token 576
# merging (101, 45) into a new token 577
# merging (319, 286) into a new token 578
# merging (296, 324) into a new token 579
# merging (119, 119) into a new token 580
# merging (359, 284) into a new token 581
# merging (455, 490) into a new token 582
# merging (205, 149) into a new token 583
# merging (204, 157) into a new token 584
# merging (204, 159) into a new token 585
# merging (204, 169) into a new token 586
# merging (204, 163) into a new token 587
# merging (205, 137) into a new token 588
# merging (32, 215) into a new token 589
# merging (102, 101) into a new token 590
# merging (526, 109) into a new token 591
# merging (442, 370) into a new token 592
# merging (102, 257) into a new token 593
# merging (118, 105) into a new token 594
# merging (111, 99) into a new token 595
# merging (443, 262) into a new token 596
# merging (566, 459) into a new token 597
# merging (509, 122) into a new token 598
# merging (98, 101) into a new token 599
# merging (103, 101) into a new token 600
# merging (347, 104) into a new token 601
# merging (601, 349) into a new token 602
# merging (602, 256) into a new token 603
# merging (319, 287) into a new token 604
# merging (110, 267) into a new token 605
# merging (266, 101) into a new token 606
# merging (300, 302) into a new token 607
# merging (65, 83) into a new token 608
# merging (608, 67) into a new token 609
# merging (609, 73) into a new token 610
# merging (303, 369) into a new token 611
# merging (102, 32) into a new token 612
# merging (292, 349) into a new token 613
# merging (115, 511) into a new token 614
# merging (115, 270) into a new token 615
# merging (615, 361) into a new token 616
# merging (410, 278) into a new token 617
# merging (114, 32) into a new token 618
# merging (99, 308) into a new token 619
# merging (619, 286) into a new token 620
# merging (111, 405) into a new token 621
# merging (112, 260) into a new token 622
# merging (101, 544) into a new token 623
# merging (105, 103) into a new token 624
# merging (579, 302) into a new token 625
# merging (625, 360) into a new token 626
# merging (119, 97) into a new token 627
# merging (322, 495) into a new token 628
# merging (296, 417) into a new token 629
# merging (323, 315) into a new token 630
# merging (353, 256) into a new token 631
# merging (582, 471) into a new token 632
# merging (204, 151) into a new token 633
# merging (205, 153) into a new token 634
# merging (204, 152) into a new token 635
# merging (204, 186) into a new token 636
# merging (204, 172) into a new token 637
# merging (204, 175) into a new token 638
# merging (205, 420) into a new token 639
# merging (67, 111) into a new token 640
# merging (257, 288) into a new token 641
# merging (103, 111) into a new token 642
# merging (72, 317) into a new token 643
# merging (264, 291) into a new token 644
# merging (41, 32) into a new token 645
# merging (101, 331) into a new token 646
# merging (610, 562) into a new token 647
# merging (106, 319) into a new token 648
# merging (648, 262) into a new token 649
# merging (269, 103) into a new token 650
# merging (97, 105) into a new token 651
# merging (114, 256) into a new token 652
# merging (119, 114) into a new token 653
# merging (102, 102) into a new token 654
# merging (104, 105) into a new token 655
# merging (97, 118) into a new token 656
# merging (259, 435) into a new token 657
# merging (657, 618) into a new token 658
# merging (344, 363) into a new token 659
# merging (353, 323) into a new token 660
# merging (397, 328) into a new token 661
# merging (66, 77) into a new token 662
# merging (662, 80) into a new token 663
# merging (70, 291) into a new token 664
# merging (385, 311) into a new token 665
# merging (259, 396) into a new token 666
# merging (280, 256) into a new token 667
# merging (419, 48) into a new token 668
# merging (413, 413) into a new token 669
# merging (368, 368) into a new token 670
# merging (205, 142) into a new token 671
# merging (215, 153) into a new token 672
# merging (65, 32) into a new token 673
# merging (117, 99) into a new token 674
# merging (33, 32) into a new token 675
# merging (438, 133) into a new token 676
# merging (438, 135) into a new token 677
# merging (591, 260) into a new token 678
# merging (488, 101) into a new token 679
# merging (116, 119) into a new token 680
# merging (415, 489) into a new token 681
# merging (41, 273) into a new token 682
# merging (364, 256) into a new token 683
# merging (268, 272) into a new token 684
# merging (115, 278) into a new token 685
# merging (101, 118) into a new token 686
# merging (257, 116) into a new token 687
# merging (564, 529) into a new token 688
# merging (284, 288) into a new token 689
# merging (643, 532) into a new token 690
# merging (690, 264) into a new token 691
# merging (270, 258) into a new token 692
# merging (351, 352) into a new token 693
# merging (118, 274) into a new token 694
# merging (268, 103) into a new token 695
# merging (293, 392) into a new token 696
# merging (109, 105) into a new token 697
# merging (280, 115) into a new token 698
# merging (268, 121) into a new token 699
# merging (293, 108) into a new token 700
# merging (653, 303) into a new token 701
# merging (309, 286) into a new token 702
# merging (316, 654) into a new token 703
# merging (703, 568) into a new token 704
# merging (311, 290) into a new token 705
# merging (279, 99) into a new token 706
# merging (422, 262) into a new token 707
# merging (617, 465) into a new token 708
# merging (104, 317) into a new token 709
# merging (347, 302) into a new token 710
# merging (342, 380) into a new token 711
# merging (323, 98) into a new token 712
# merging (283, 115) into a new token 713
# merging (275, 271) into a new token 714
# merging (276, 466) into a new token 715
# merging (660, 103) into a new token 716
# merging (110, 277) into a new token 717
# merging (104, 440) into a new token 718
# merging (109, 347) into a new token 719
# merging (59, 32) into a new token 720
# merging (623, 32) into a new token 721
# merging (397, 115) into a new token 722
# merging (545, 297) into a new token 723
# merging (41, 428) into a new token 724
# merging (339, 258) into a new token 725
# merging (119, 313) into a new token 726
# merging (102, 266) into a new token 727
# merging (121, 45) into a new token 728
# merging (664, 626) into a new token 729
# merging (398, 284) into a new token 730
# merging (403, 100) into a new token 731
# merging (115, 324) into a new token 732
# merging (108, 650) into a new token 733
# merging (401, 603) into a new token 734
# merging (734, 451) into a new token 735
# merging (735, 604) into a new token 736
# merging (355, 226) into a new token 737
# merging (737, 151) into a new token 738
# merging (738, 140) into a new token 739
# merging (517, 454) into a new token 740
# merging (205, 156) into a new token 741
# merging (204, 174) into a new token 742
# merging (204, 156) into a new token 743
# merging (480, 575) into a new token 744
# merging (78, 70) into a new token 745
# merging (67, 357) into a new token 746
# merging (239, 189) into a new token 747
# merging (263, 140) into a new token 748
# merging (748, 677) into a new token 749
# merging (119, 256) into a new token 750
# merging (319, 284) into a new token 751
# merging (268, 267) into a new token 752
# merging (685, 380) into a new token 753
# merging (101, 112) into a new token 754
# merging (119, 32) into a new token 755
# merging (257, 287) into a new token 756
# merging (306, 380) into a new token 757
# merging (118, 286) into a new token 758
# merging (403, 107) into a new token 759
# merging (429, 258) into a new token 760
# merging (297, 285) into a new token 761
# merging (108, 97) into a new token 762
# merging (265, 276) into a new token 763
# merging (32, 289) into a new token 764
# merging (607, 296) into a new token 765
# merging (111, 469) into a new token 766
# merging (117, 371) into a new token 767
# merging (110, 463) into a new token 768
# merging (768, 98) into a new token 769
# merging (696, 32) into a new token 770
# merging (537, 105) into a new token 771
# merging (697, 558) into a new token 772
# merging (270, 264) into a new token 773
# merging (269, 278) into a new token 774
# merging (572, 613) into a new token 775
# merging (293, 605) into a new token 776
# merging (116, 372) into a new token 777
# merging (98, 111) into a new token 778
# merging (109, 111) into a new token 779
# merging (569, 407) into a new token 780
# merging (116, 114) into a new token 781
# merging (348, 396) into a new token 782
# merging (300, 109) into a new token 783
# merging (97, 447) into a new token 784
# merging (266, 574) into a new token 785
# merging (712, 361) into a new token 786
# merging (101, 116) into a new token 787
# merging (115, 299) into a new token 788
# merging (453, 32) into a new token 789
# merging (259, 101) into a new token 790
# merging (279, 116) into a new token 791
# merging (594, 350) into a new token 792
# merging (354, 275) into a new token 793
# merging (350, 114) into a new token 794
# merging (326, 103) into a new token 795
# merging (382, 498) into a new token 796
# merging (99, 427) into a new token 797
# merging (99, 256) into a new token 798
# merging (315, 32) into a new token 799
# merging (58, 428) into a new token 800
# merging (272, 288) into a new token 801
# merging (257, 100) into a new token 802
# merging (286, 313) into a new token 803
# merging (363, 499) into a new token 804
# merging (406, 32) into a new token 805
# merging (338, 111) into a new token 806
# merging (351, 384) into a new token 807
# merging (100, 121) into a new token 808
# merging (808, 557) into a new token 809
# merging (386, 630) into a new token 810
# merging (98, 631) into a new token 811
# merging (58, 480) into a new token 812
# merging (322, 100) into a new token 813
# merging (355, 225) into a new token 814
# merging (204, 165) into a new token 815
# merging (205, 157) into a new token 816
# merging (204, 153) into a new token 817
# merging (204, 168) into a new token 818
# merging (204, 420) into a new token 819
# merging (215, 170) into a new token 820
# merging (524, 744) into a new token 821
# merging (73, 110) into a new token 822
# merging (100, 674) into a new token 823
# merging (640, 100) into a new token 824
# merging (269, 318) into a new token 825
# merging (403, 108) into a new token 826
# merging (273, 87) into a new token 827
# merging (107, 110) into a new token 828
# merging (116, 328) into a new token 829
# merging (431, 446) into a new token 830
# merging (598, 533) into a new token 831
# merging (358, 115) into a new token 832
# merging (374, 105) into a new token 833
# merging (833, 694) into a new token 834
# merging (262, 288) into a new token 835
# merging (117, 100) into a new token 836
# merging (488, 360) into a new token 837
# merging (695, 256) into a new token 838
# merging (342, 259) into a new token 839
# merging (366, 431) into a new token 840
# merging (840, 257) into a new token 841
# merging (841, 258) into a new token 842
# merging (290, 109) into a new token 843
# merging (769, 310) into a new token 844
# merging (844, 285) into a new token 845
# merging (104, 472) into a new token 846
# merging (117, 330) into a new token 847
# merging (847, 272) into a new token 848
# merging (338, 108) into a new token 849
# merging (273, 65) into a new token 850
# merging (100, 309) into a new token 851
# merging (476, 379) into a new token 852
# merging (259, 260) into a new token 853
# merging (276, 103) into a new token 854
# merging (264, 478) into a new token 855
# merging (338, 361) into a new token 856
# merging (257, 451) into a new token 857
# merging (505, 280) into a new token 858
# merging (858, 539) into a new token 859
# merging (331, 77) into a new token 860
# merging (104, 784) into a new token 861
# merging (104, 470) into a new token 862
# merging (348, 372) into a new token 863
# merging (298, 339) into a new token 864
# merging (350, 371) into a new token 865
# merging (49, 50) into a new token 866
# merging (268, 101) into a new token 867
# merging (117, 352) into a new token 868
# merging (714, 535) into a new token 869
# merging (116, 264) into a new token 870
# merging (114, 404) into a new token 871
# merging (54, 32) into a new token 872
# merging (54, 53) into a new token 873
# merging (716, 110) into a new token 874
# merging (874, 286) into a new token 875
# merging (115, 109) into a new token 876
# merging (108, 449) into a new token 877
# merging (115, 262) into a new token 878
# merging (80, 108) into a new token 879
# merging (879, 265) into a new token 880
# merging (313, 275) into a new token 881
# merging (75, 606) into a new token 882
# merging (32, 40) into a new token 883
# merging (109, 389) into a new token 884
# merging (73, 423) into a new token 885
# merging (98, 367) into a new token 886
# merging (275, 393) into a new token 887
# merging (548, 32) into a new token 888
# merging (573, 97) into a new token 889
# merging (889, 278) into a new token 890
# merging (890, 98) into a new token 891
# merging (323, 496) into a new token 892
# merging (802, 296) into a new token 893
# merging (412, 379) into a new token 894
# merging (289, 290) into a new token 895
# merging (269, 100) into a new token 896
# merging (342, 100) into a new token 897
# merging (61, 355) into a new token 898
# merging (367, 272) into a new token 899
# merging (435, 405) into a new token 900
# merging (259, 667) into a new token 901
# merging (436, 329) into a new token 902
# merging (804, 344) into a new token 903
# merging (358, 323) into a new token 904
# merging (105, 287) into a new token 905
# merging (302, 279) into a new token 906
# merging (259, 284) into a new token 907
# merging (306, 652) into a new token 908
# merging (115, 331) into a new token 909
# merging (258, 275) into a new token 910
# merging (259, 372) into a new token 911
# merging (629, 454) into a new token 912
# merging (627, 121) into a new token 913
# merging (109, 708) into a new token 914
# merging (259, 692) into a new token 915
# merging (355, 195) into a new token 916
# merging (187, 135) into a new token 917
# merging (205, 152) into a new token 918
# merging (205, 154) into a new token 919
# merging (225, 184) into a new token 920
# merging (317, 367) into a new token 921
# merging (214, 180) into a new token 922
# merging (813, 812) into a new token 923
# merging (326, 823) into a new token 924
# merging (101, 268) into a new token 925
# merging (109, 101) into a new token 926
# merging (115, 378) into a new token 927
# merging (392, 116) into a new token 928
# merging (66, 441) into a new token 929
# merging (302, 349) into a new token 930
# merging (278, 109) into a new token 931
# merging (100, 276) into a new token 932
# merging (932, 430) into a new token 933
# merging (98, 108) into a new token 934
# merging (258, 337) into a new token 935
# merging (99, 754) into a new token 936
# merging (116, 286) into a new token 937
# merging (289, 327) into a new token 938
# merging (333, 268) into a new token 939
# merging (422, 423) into a new token 940
# merging (642, 689) into a new token 941
# merging (530, 322) into a new token 942
# merging (111, 108) into a new token 943
# merging (565, 507) into a new token 944
# merging (259, 567) into a new token 945
# merging (945, 256) into a new token 946
# merging (112, 268) into a new token 947
# merging (261, 112) into a new token 948
# merging (104, 260) into a new token 949
# merging (824, 535) into a new token 950
# merging (85, 115) into a new token 951
# merging (305, 495) into a new token 952
# merging (952, 272) into a new token 953
# merging (395, 831) into a new token 954
# merging (259, 770) into a new token 955
# merging (273, 327) into a new token 956
# merging (115, 771) into a new token 957
# merging (109, 767) into a new token 958
# merging (322, 256) into a new token 959
# merging (87, 104) into a new token 960
# merging (100, 277) into a new token 961
# merging (323, 109) into a new token 962
# merging (115, 266) into a new token 963
# merging (409, 111) into a new token 964
# merging (964, 465) into a new token 965
# merging (258, 289) into a new token 966
# merging (476, 297) into a new token 967
# merging (49, 363) into a new token 968
# merging (293, 258) into a new token 969
# merging (98, 114) into a new token 970
# merging (561, 111) into a new token 971
# merging (256, 285) into a new token 972
# merging (351, 365) into a new token 973
# merging (264, 327) into a new token 974
# merging (303, 121) into a new token 975
# merging (109, 265) into a new token 976
# merging (264, 542) into a new token 977
# merging (709, 402) into a new token 978
# merging (357, 32) into a new token 979
# merging (286, 479) into a new token 980
# merging (411, 393) into a new token 981
# merging (981, 120) into a new token 982
# merging (865, 313) into a new token 983
# merging (320, 108) into a new token 984
# merging (984, 309) into a new token 985
# merging (985, 289) into a new token 986
# merging (866, 56) into a new token 987
# merging (50, 51) into a new token 988
# merging (101, 378) into a new token 989
# merging (257, 316) into a new token 990
# merging (388, 593) into a new token 991
# merging (600, 262) into a new token 992
# merging (107, 402) into a new token 993
# merging (122, 111) into a new token 994
# merging (994, 357) into a new token 995
# merging (328, 301) into a new token 996
# merging (794, 795) into a new token 997
# merging (376, 345) into a new token 998
# merging (366, 99) into a new token 999

# %%
print("tokens length:", len(tokens))
print("ids length:", len(ids))
print(f"compression ratio: {len(tokens) / len(ids):.2f}X")
# Out:
# tokens length: 24597
# ids length: 8120
# compression ratio: 3.03X

# %% [markdown]
# the logic is similar to a binary tree but instead of starting at the root we are starting at leaves and working our way to the root

# %%
vocab = {idx: bytes([idx]) for idx in range(256)} # Start with the 256 base bytes
# Go through the merges we made and piece together the bytes for our new tokens bascially the new tokens we created 
for (p0, p1), idx in merges.items():
    vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
  # given ids (list of integers), return Python string
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors="replace")
  return text

# %% [markdown]
# all errors for 0x80 decoding error which occurs in utf-8 are replaced with  '�'

# %%
decode([128])
# Out:
# '�'

# %%
decode([697])
# Out:
# 'mi'

# %%
merges
# Out:
# {(101, 32): 256,
#  (105, 110): 257,
#  (115, 32): 258,
#  (116, 104): 259,
#  (101, 114): 260,
#  (99, 111): 261,
#  (116, 32): 262,
#  (226, 128): 263,
#  (44, 32): 264,
#  (97, 110): 265,
#  (111, 114): 266,
#  (100, 32): 267,
#  (97, 114): 268,
#  (101, 110): 269,
#  (257, 103): 270,
#  (261, 100): 271,
#  (121, 32): 272,
#  (46, 32): 273,
#  (97, 108): 274,
#  (259, 256): 275,
#  (111, 110): 276,
#  (111, 32): 277,
#  (116, 105): 278,
#  (97, 99): 279,
#  (101, 115): 280,
#  (111, 102): 281,
#  (271, 256): 282,
#  (112, 111): 283,
#  (270, 32): 284,
#  (281, 32): 285,
#  (101, 267): 286,
#  (116, 260): 287,
#  (116, 277): 288,
#  (257, 32): 289,
#  (97, 32): 290,
#  (266, 32): 291,
#  (115, 116): 292,
#  (111, 117): 293,
#  (99, 104): 294,
#  (120, 120): 295,
#  (101, 120): 296,
#  (101, 258): 297,
#  (263, 156): 298,
#  (263, 157): 299,
#  (261, 109): 300,
#  (265, 267): 301,
#  (112, 108): 302,
#  (105, 116): 303,
#  (283, 257): 304,
#  (114, 101): 305,
#  (263, 153): 306,
#  (110, 105): 307,
#  (274, 108): 308,
#  (97, 116): 309,
#  (260, 32): 310,
#  (105, 258): 311,
#  (282, 304): 312,
#  (97, 258): 313,
#  (85, 307): 314,
#  (278, 276): 315,
#  (100, 105): 316,
#  (111, 119): 317,
#  (116, 258): 318,
#  (117, 115): 319,
#  (299, 32): 320,
#  (114, 105): 321,
#  (115, 101): 322,
#  (115, 105): 323,
#  (97, 109): 324,
#  (97, 262): 325,
#  (114, 111): 326,
#  (314, 282): 327,
#  (115, 264): 328,
#  (121, 121): 329,
#  (108, 108): 330,
#  (273, 32): 331,
#  (265, 32): 332,
#  (108, 101): 333,
#  (294, 268): 334,
#  (279, 287): 335,
#  (84, 104): 336,
#  (102, 291): 337,
#  (97, 98): 338,
#  (334, 335): 339,
#  (85, 84): 340,
#  (340, 70): 341,
#  (119, 105): 342,
#  (341, 45): 343,
#  (85, 43): 344,
#  (268, 256): 345,
#  (259, 325): 346,
#  (97, 112): 347,
#  (119, 104): 348,
#  (101, 109): 349,
#  (115, 117): 350,
#  (105, 99): 351,
#  (274, 32): 352,
#  (97, 115): 353,
#  (32, 285): 354,
#  (32, 298): 355,
#  (105, 262): 356,
#  (111, 109): 357,
#  (118, 260): 358,
#  (292, 114): 359,
#  (101, 264): 360,
#  (108, 256): 361,
#  (278, 99): 362,
#  (48, 48): 363,
#  (97, 103): 364,
#  (97, 315): 365,
#  (261, 110): 366,
#  (101, 108): 367,
#  (295, 295): 368,
#  (306, 258): 369,
#  (98, 256): 370,
#  (294, 32): 371,
#  (269, 32): 372,
#  (259, 32): 373,
#  (113, 117): 374,
#  (114, 280): 375,
#  (312, 318): 376,
#  (116, 296): 377,
#  (100, 111): 505,
#  (258, 285): 506,
#  (338, 445): 507,
#  (262, 285): 508,
#  (274, 105): 509,
#  (99, 321): 510,
#  (510, 112): 511,
#  (461, 32): 512,
#  (116, 284): 513,
#  (101, 100): 514,
#  (292, 266): 515,
#  (398, 270): 516,
#  (411, 386): 517,
#  (204, 187): 518,
#  (204, 170): 519,
#  (204, 179): 520,
#  (205, 141): 521,
#  (204, 188): 522,
#  (204, 173): 523,
#  (320, 43): 524,
#  (50, 32): 525,
#  (421, 504): 526,
#  (105, 100): 527,
#  (286, 288): 528,
#  (109, 32): 529,
#  (339, 32): 530,
#  (377, 116): 531,
#  (101, 358): 532,
#  (365, 32): 533,
#  (309, 256): 534,
#  (460, 256): 535,
#  (274, 432): 536,
#  (409, 99): 537,
#  (276, 256): 538,
#  (110, 430): 539,
#  (385, 256): 540,
#  (97, 100): 541,
#  (98, 441): 542,
#  (268, 105): 543,
#  (279, 104): 544,
#  (302, 265): 545,
#  (117, 116): 546,
#  (102, 395): 547,
#  (117, 112): 548,
#  (49, 48): 549,
#  (205, 133): 550,
#  (204, 160): 551,
#  (204, 150): 552,
#  (205, 147): 553,
#  (204, 164): 554,
#  (205, 148): 555,
#  (336, 256): 556,
#  (110, 324): 557,
#  (392, 262): 558,
#  (486, 487): 559,
#  (303, 258): 560,
#  (290, 108): 561,
#  (73, 32): 562,
#  (491, 256): 563,
#  (102, 326): 564,
#  (107, 32): 565,
#  (114, 269): 566,
#  (111, 115): 567,
#  (260, 416): 568,
#  (305, 417): 569,
#  (264, 301): 570,
#  (258, 288): 571,
#  (115, 121): 572,
#  (300, 112): 573,
#  (100, 310): 574,
#  (48, 51): 575,
#  (116, 111): 576,
#  (101, 45): 577,
#  (319, 286): 578,
#  (296, 324): 579,
#  (119, 119): 580,
#  (359, 284): 581,
#  (455, 490): 582,
#  (205, 149): 583,
#  (204, 157): 584,
#  (204, 159): 585,
#  (204, 169): 586,
#  (204, 163): 587,
#  (205, 137): 588,
#  (32, 215): 589,
#  (102, 101): 590,
#  (526, 109): 591,
#  (442, 370): 592,
#  (102, 257): 593,
#  (118, 105): 594,
#  (111, 99): 595,
#  (443, 262): 596,
#  (566, 459): 597,
#  (509, 122): 598,
#  (98, 101): 599,
#  (103, 101): 600,
#  (347, 104): 601,
#  (601, 349): 602,
#  (602, 256): 603,
#  (319, 287): 604,
#  (110, 267): 605,
#  (266, 101): 606,
#  (300, 302): 607,
#  (65, 83): 608,
#  (608, 67): 609,
#  (609, 73): 610,
#  (303, 369): 611,
#  (102, 32): 612,
#  (292, 349): 613,
#  (115, 511): 614,
#  (115, 270): 615,
#  (615, 361): 616,
#  (410, 278): 617,
#  (114, 32): 618,
#  (99, 308): 619,
#  (619, 286): 620,
#  (111, 405): 621,
#  (112, 260): 622,
#  (101, 544): 623,
#  (105, 103): 624,
#  (579, 302): 625,
#  (625, 360): 626,
#  (119, 97): 627,
#  (322, 495): 628,
#  (296, 417): 629,
#  (323, 315): 630,
#  (353, 256): 631,
#  (582, 471): 632,
#  (548, 32): 888,
#  (573, 97): 889,
#  (889, 278): 890,
#  (890, 98): 891,
#  (323, 496): 892,
#  (802, 296): 893,
#  (412, 379): 894,
#  (289, 290): 895,
#  (269, 100): 896,
#  (342, 100): 897,
#  (61, 355): 898,
#  (367, 272): 899,
#  (435, 405): 900,
#  (259, 667): 901,
#  (436, 329): 902,
#  (804, 344): 903,
#  (358, 323): 904,
#  (105, 287): 905,
#  (302, 279): 906,
#  (259, 284): 907,
#  (306, 652): 908,
#  (115, 331): 909,
#  (258, 275): 910,
#  (259, 372): 911,
#  (629, 454): 912,
#  (627, 121): 913,
#  (109, 708): 914,
#  (259, 692): 915,
#  (355, 195): 916,
#  (187, 135): 917,
#  (205, 152): 918,
#  (205, 154): 919,
#  (225, 184): 920,
#  (317, 367): 921,
#  (214, 180): 922,
#  (813, 812): 923,
#  (326, 823): 924,
#  (101, 268): 925,
#  (109, 101): 926,
#  (115, 378): 927,
#  (392, 116): 928,
#  (66, 441): 929,
#  (302, 349): 930,
#  (278, 109): 931,
#  (100, 276): 932,
#  (932, 430): 933,
#  (98, 108): 934,
#  (258, 337): 935,
#  (99, 754): 936,
#  (116, 286): 937,
#  (289, 327): 938,
#  (333, 268): 939,
#  (422, 423): 940,
#  (642, 689): 941,
#  (530, 322): 942,
#  (111, 108): 943,
#  (565, 507): 944,
#  (259, 567): 945,
#  (945, 256): 946,
#  (112, 268): 947,
#  (261, 112): 948,
#  (104, 260): 949,
#  (824, 535): 950,
#  (85, 115): 951,
#  (305, 495): 952,
#  (952, 272): 953,
#  (395, 831): 954,
#  (259, 770): 955,
#  (273, 327): 956,
#  (115, 771): 957,
#  (109, 767): 958,
#  (322, 256): 959,
#  (87, 104): 960,
#  (100, 277): 961,
#  (323, 109): 962,
#  (115, 266): 963,
#  (409, 111): 964,
#  (964, 465): 965,
#  (258, 289): 966,
#  (476, 297): 967,
#  (49, 363): 968,
#  (293, 258): 969,
#  (98, 114): 970,
#  (561, 111): 971,
#  (256, 285): 972,
#  (351, 365): 973,
#  (264, 327): 974,
#  (303, 121): 975,
#  (109, 265): 976,
#  (264, 542): 977,
#  (709, 402): 978,
#  (357, 32): 979,
#  (286, 479): 980,
#  (411, 393): 981,
#  (981, 120): 982,
#  (865, 313): 983,
#  (320, 108): 984,
#  (984, 309): 985,
#  (985, 289): 986,
#  (866, 56): 987,
#  (50, 51): 988,
#  (101, 378): 989,
#  (257, 316): 990,
#  (388, 593): 991,
#  (600, 262): 992,
#  (107, 402): 993,
#  (122, 111): 994,
#  (994, 357): 995,
#  (328, 301): 996,
#  (794, 795): 997,
#  (376, 345): 998,
#  (366, 99): 999}

# %%
def encode(text):
  # given a string, return list of integers (the tokens)
  tokens = list(text.encode("utf-8"))
  while len(tokens) >= 2:
    stats = get_stats(tokens)
    pair = min(stats, key=lambda p: merges.get(p, float("inf")))
    if pair not in merges:
      break # nothing else can be merged
    idx = merges[pair]
    tokens = merge(tokens, pair, idx)
  return tokens

print(encode(""))
# Out:
# []
